# %% [markdown]
# <a href="https://colab.research.google.com/github/wojtek2kdev/Obliczenia_naukowe/blob/main/zadDomowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imię

# %%
name = input("Podaj imie: ")
print(f"Hello {name}")
# Out:
# Podaj imie: Wojtek
# Hello Wojtek

# %% [markdown]
# #Kod skryptu
#
# ```python
# name = input("Podaj imie: ")
# print(f"Hello {name}")
# ```

# %% [markdown]
# #Obrazek
# ![d22233cf86255788ff68c7f6ae2b9837.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Funkcja python

# %%
import numpy as np

def listownik():
  s = int(input("Podaj dlugosc listy w przedziale {10..20}: "))
  while not 10<=s<=20:
    s = int(input("Błąd.\nPodaj dlugosc listy w przedziale {10..20}: "))
  T = np.random.randint(0, 11, size=s)
  print(T)
  return len(set(T))

listownik()
# Out:
# Podaj dlugosc listy w przedziale {10..20}: 8
# Błąd.
# Podaj dlugosc listy w przedziale {10..20}: 23
# Błąd.
# Podaj dlugosc listy w przedziale {10..20}: 13
# [ 3  1  6  5  2 10  3  9  7  2  3  8  6]
# 9
